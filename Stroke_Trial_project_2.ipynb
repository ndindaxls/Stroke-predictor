# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/Datasets/healthcare-dataset-stroke-data (1).csv')

df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
df['stroke'].unique()
# Out:
# array([1, 0])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   object
#  2   age                5110 non-null   float64
#  3   hypertension       5110 non-null   int64
#  4   heart_disease      5110 non-null   int64
#  5   ever_married       5110 non-null   object
#  6   work_type          5110 non-null   object
#  7   Residence_type     5110 non-null   object
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                4909 non-null   float64
#  10  smoking_status     5110 non-null   object
#  11  stroke             5110 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 479.2+ KB

# %% [markdown]
# I ran this cell to in order to confirm whether the data cell had any null values and check the data types

# %%
df.isna().sum()
# Out:
# id                     0
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# stroke                 0
# dtype: int64

# %%
df['bmi'].unique()
# Out:
# array([36.6,  nan, 32.5, 34.4, 24. , 29. , 27.4, 22.8, 24.2, 29.7, 36.8,
#        27.3, 28.2, 30.9, 37.5, 25.8, 37.8, 22.4, 48.9, 26.6, 27.2, 23.5,
#        28.3, 44.2, 25.4, 22.2, 30.5, 26.5, 33.7, 23.1, 32. , 29.9, 23.9,
#        28.5, 26.4, 20.2, 33.6, 38.6, 39.2, 27.7, 31.4, 36.5, 33.2, 32.8,
#        40.4, 25.3, 30.2, 47.5, 20.3, 30. , 28.9, 28.1, 31.1, 21.7, 27. ,
#        24.1, 45.9, 44.1, 22.9, 29.1, 32.3, 41.1, 25.6, 29.8, 26.3, 26.2,
#        29.4, 24.4, 28. , 28.8, 34.6, 19.4, 30.3, 41.5, 22.6, 56.6, 27.1,
#        31.3, 31. , 31.7, 35.8, 28.4, 20.1, 26.7, 38.7, 34.9, 25. , 23.8,
#        21.8, 27.5, 24.6, 32.9, 26.1, 31.9, 34.1, 36.9, 37.3, 45.7, 34.2,
#        23.6, 22.3, 37.1, 45. , 25.5, 30.8, 37.4, 34.5, 27.9, 29.5, 46. ,
#        42.5, 35.5, 26.9, 45.5, 31.5, 33. , 23.4, 30.7, 20.5, 21.5, 40. ,
#        28.6, 42.2, 29.6, 35.4, 16.9, 26.8, 39.3, 32.6, 35.9, 21.2, 42.4,
#        40.5, 36.7, 29.3, 19.6, 18. , 17.6, 19.1, 50.1, 17.7, 54.6, 35. ,
# ...

# %%
df['bmi'] = df['bmi'].fillna(df['bmi'].mean())

# %%
df['gender'].unique()
# Out:
# array(['Male', 'Female', 'Other'], dtype=object)

# %%
df.loc[df['gender'] == 'Male' 'gender'] = 'M'
df.loc[df['gender'] == 'Female' 'gender'] = 'F'

# %% [markdown]
# I ran the first code to check whether the first code needed any cleaning

# %%
male_df= df[df["gender"]== "male"]
female_df= df[df["gender"]== "female"]
other_df= df[df["gender"]== "other"]

# %% [markdown]
# I filtered the male and female into different datasets

# %%
df["gender"].value_counts()
# Out:
# gender
# Female    2994
# Male      2115
# Other        1
# Name: count, dtype: int64

# %% [markdown]
# I had 5100 people in the dataset. 2994 females, 2115 males

# %%
df["gender"].value_counts(normalize=True)*100
# Out:
# gender
# Female    58.590998
# Male      41.389432
# Other      0.019569
# Name: proportion, dtype: float64

# %% [markdown]
# I got the percentages of the genders

# %%
df.groupby("gender")["age"].value_counts()
# Out:
# gender  age
# Female  45.00    61
#         78.00    60
#         79.00    59
#         50.00    55
#         51.00    54
#                  ..
# Male    0.48      1
#         1.24      1
#         1.40      1
#         1.48      1
# Other   26.00     1
# Name: count, Length: 206, dtype: int64

# %% [markdown]
# The age in males is in decimals because it is a baby and the term is written in float. Males have more prediction analysis as opposed to females

# %%
df.groupby("gender")["hypertension"].value_counts(normalize=True)*100
# Out:
# gender  hypertension
# Female  0                90.781563
#         1                 9.218437
# Male    0                89.503546
#         1                10.496454
# Other   0               100.000000
# Name: proportion, dtype: float64

# %% [markdown]
# A higher percentage of females have less hypertension as compared to those who do not have.
#
# A higher percentage of males have less hypertension as compared to those who do not have.

# %%
df.groupby("gender")["heart_disease"].value_counts(normalize=True)*100 #
# Out:
# gender  heart_disease
# Female  0                 96.225785
#         1                  3.774215
# Male    0                 92.293144
#         1                  7.706856
# Other   0                100.000000
# Name: proportion, dtype: float64

# %% [markdown]
# - Males show a slightly higher proportion of heart disease cases compared to females.
# - No heart disease cases were recorded for individuals classified as other

# %%
df.groupby("gender")["ever_married"].value_counts(normalize=True)*100 #
# Out:
# gender  ever_married
# Female  Yes              66.833667
#         No               33.166333
# Male    Yes              63.924350
#         No               36.075650
# Other   No              100.000000
# Name: proportion, dtype: float64

# %% [markdown]
# - A slightly higher proportion of females have been married compared to males.
# - All individuals in the 'other' category reported never being married

# %%
df['Residence_type'].value_counts()
# Out:
# Residence_type
# Urban    2596
# Rural    2514
# Name: count, dtype: int64

# %% [markdown]
# - I got the residency of where most patients live. Majority of them live in Urban areas

# %%
df.groupby("avg_glucose_level")["Residence_type"].value_counts()
# Out:
# avg_glucose_level  Residence_type
# 55.12              Rural             1
# 55.22              Urban             1
# 55.23              Rural             1
# 55.25              Urban             1
# 55.26              Rural             1
#                                     ..
# 266.59             Rural             1
# 267.60             Rural             1
# 267.61             Urban             1
# 267.76             Urban             1
# 271.74             Rural             1
# Name: count, Length: 4503, dtype: int64

# %% [markdown]
# - Urban residents tend to have slightly higher glucose levels compared to rural residents possibly due tio lifestyle and dietary differences

# %%
df.groupby("bmi")["Residence_type"].value_counts(normalize=True)*100
# Out:
# bmi   Residence_type
# 10.3  Rural             100.0
# 11.3  Urban             100.0
# 11.5  Rural             100.0
# 12.0  Urban             100.0
# 12.3  Urban             100.0
#                         ...
# 66.8  Rural             100.0
# 71.9  Rural             100.0
# 78.0  Urban             100.0
# 92.0  Rural             100.0
# 97.6  Rural             100.0
# Name: proportion, Length: 734, dtype: float64

# %% [markdown]
# - Each BMI value and smoking status category, the proportion for a residence type was consistently 100% implying that each group contained only one residence type

# %%
df.groupby("smoking_status")["Residence_type"].value_counts(normalize=True)*100
# Out:
# smoking_status   Residence_type
# Unknown          Urban             50.647668
#                  Rural             49.352332
# formerly smoked  Urban             51.638418
#                  Rural             48.361582
# never smoked     Rural             50.792812
#                  Urban             49.207188
# smokes           Urban             53.992395
#                  Rural             46.007605
# Name: proportion, dtype: float64

# %% [markdown]
# - The proportion of each residency type

# %%
df['avg_glucose_level'].value_counts()
# Out:
# avg_glucose_level
# 93.88     6
# 73.00     5
# 72.49     5
# 91.85     5
# 91.68     5
#          ..
# 61.98     1
# 91.01     1
# 120.03    1
# 138.51    1
# 118.41    1
# Name: count, Length: 3979, dtype: int64

# %% [markdown]
# - I got the average glucose levels of patients.

# %%
df.groupby("avg_glucose_level")["smoking_status"].value_counts(normalize=True)*100
# Out:
# avg_glucose_level  smoking_status
# 55.12              never smoked       100.0
# 55.22              never smoked       100.0
# 55.23              Unknown            100.0
# 55.25              never smoked       100.0
# 55.26              Unknown            100.0
#                                       ...
# 266.59             never smoked       100.0
# 267.60             never smoked       100.0
# 267.61             smokes             100.0
# 267.76             formerly smoked    100.0
# 271.74             smokes             100.0
# Name: proportion, Length: 4735, dtype: float64

# %% [markdown]
# - The code calculates and displays the proportion of each smoking status for different average glucose levels

# %%
df.groupby("avg_glucose_level")["bmi"].value_counts(normalize=True)*100
# Out:
# avg_glucose_level  bmi
# 55.12              21.8    100.0
# 55.22              27.0    100.0
# 55.23              28.9    100.0
# 55.25              20.4    100.0
# 55.26              33.2    100.0
#                            ...
# 266.59             25.5    100.0
# 267.60             30.5    100.0
# 267.61             27.9    100.0
# 267.76             29.3    100.0
# 271.74             31.1    100.0
# Name: proportion, Length: 5103, dtype: float64

# %% [markdown]
# - The code displays the proportion of each BMI value for different glucose values

# %%
df.groupby("bmi").value_counts()
# Out:
# bmi   id     gender  age    hypertension  heart_disease  ever_married  work_type      Residence_type  avg_glucose_level  smoking_status  stroke
# 10.3  38043  Female  1.24   0             0              No            children       Rural           122.04             Unknown         0         1
# 11.3  3205   Female  79.00  0             0              Yes           Self-employed  Urban           79.03              Unknown         0         1
# 11.5  59993  Male    40.00  0             0              Yes           Private        Rural           60.96              never smoked    0         1
# 12.0  20364  Female  4.00   0             0              No            children       Urban           107.25             Unknown         0         1
# 12.3  45893  Female  8.00   0             0              No            children       Urban           106.51             Unknown         0         1
# ...

# %% [markdown]
# - The code displays the bmi in accordance to one's marriage status, smoking status, residence type and work type

# %%
df.groupby("bmi")["smoking_status"].value_counts(normalize=True)*100
# Out:
# bmi   smoking_status
# 10.3  Unknown           100.0
# 11.3  Unknown           100.0
# 11.5  never smoked      100.0
# 12.0  Unknown           100.0
# 12.3  Unknown           100.0
#                         ...
# 66.8  Unknown           100.0
# 71.9  never smoked      100.0
# 78.0  smokes            100.0
# 92.0  never smoked      100.0
# 97.6  Unknown           100.0
# Name: proportion, Length: 1194, dtype: float64

# %% [markdown]
# - The code displays the bmi value according to one's smoking status

# %%
ratings_mean_count = pd.DataFrame(df.groupby('gender')['stroke'].mean())
ratings_mean_count['rating_counts'] = pd.DataFrame(df.groupby('gender')['stroke'].count())
ratings_mean_count
# Out:
#           stroke  rating_counts
# gender
# Female  0.047094           2994
# Male    0.051064           2115
# Other   0.000000              1

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8,6))
plt.rcParams['patch.force_edgecolor'] = True
ratings_mean_count['stroke'].plot.bar()
# Out:
# <Axes: xlabel='gender'>

# %% [markdown]
# AGE DISTRIBUTION GRAPH

# %%
df.describe()
# Out:
#                  id          age  hypertension  heart_disease  \
# count   5110.000000  5110.000000   5110.000000    5110.000000
# mean   36517.829354    43.226614      0.097456       0.054012
# std    21161.721625    22.612647      0.296607       0.226063
# min       67.000000     0.080000      0.000000       0.000000
# 25%    17741.250000    25.000000      0.000000       0.000000
# 50%    36932.000000    45.000000      0.000000       0.000000
# 75%    54682.000000    61.000000      0.000000       0.000000
# max    72940.000000    82.000000      1.000000       1.000000
#
#        avg_glucose_level          bmi       stroke
# count        5110.000000  5110.000000  5110.000000
# mean          106.147677    28.893237     0.048728
# std            45.283560     7.698018     0.215320
# min            55.120000    10.300000     0.000000
# 25%            77.245000    23.800000     0.000000
# 50%            91.885000    28.400000     0.000000
# ...

# %%
sns.histplot(df['age'])
plt.xlabel('Age')
plt.ylabel('Count')
plt.title('Age Distribution')
plt.show()

# %% [markdown]
# #BMI GRAPH

# %%
sns.boxplot(x='gender', y='bmi', data=df)
plt.xlabel('Gender')
plt.ylabel('BMI')
plt.title('Comparison of BMI Distribution by Gender')
plt.show()

# %%
kmf = df.groupby('gender')['bmi'].mean()
kmf
# Out:
# gender
# Female    29.060168
# Male      28.659998
# Other     22.400000
# Name: bmi, dtype: float64

# %% [markdown]
# CORRELATION MATRIX

# %%
for col in df.columns:
  print(col, 'number of unique values is :', df[col].nunique())
  print(df[col].unique())
  print ('\n')
# Out:
# id number of unique values is : 5110
# [ 9046 51676 31112 ... 19723 37544 44679]
#
#
# gender number of unique values is : 3
# ['Male' 'Female' 'Other']
#
#
# age number of unique values is : 104
# [6.70e+01 6.10e+01 8.00e+01 4.90e+01 7.90e+01 8.10e+01 7.40e+01 6.90e+01
#  5.90e+01 7.80e+01 5.40e+01 5.00e+01 6.40e+01 7.50e+01 6.00e+01 5.70e+01
#  7.10e+01 5.20e+01 8.20e+01 6.50e+01 5.80e+01 4.20e+01 4.80e+01 7.20e+01
#  6.30e+01 7.60e+01 3.90e+01 7.70e+01 7.30e+01 5.60e+01 4.50e+01 7.00e+01
#  6.60e+01 5.10e+01 4.30e+01 6.80e+01 4.70e+01 5.30e+01 3.80e+01 5.50e+01
#  1.32e+00 4.60e+01 3.20e+01 1.40e+01 3.00e+00 8.00e+00 3.70e+01 4.00e+01
#  3.50e+01 2.00e+01 4.40e+01 2.50e+01 2.70e+01 2.30e+01 1.70e+01 1.30e+01
#  4.00e+00 1.60e+01 2.20e+01 3.00e+01 2.90e+01 1.10e+01 2.10e+01 1.80e+01
#  3.30e+01 2.40e+01 3.40e+01 3.60e+01 6.40e-01 4.10e+01 8.80e-01 5.00e+00
#  2.60e+01 3.10e+01 7.00e+00 1.20e+01 6.20e+01 2.00e+00 9.00e+00 1.50e+01
# ...

# %%
for col in df.columns:
  print(col, 'number of unique values is :', df[col].nunique())
  print("value counts is :", df[col].value_counts())
  print ('----------------------')
# Out:
# id number of unique values is : 5110
# value counts is : id
# 44679    1
# 9046     1
# 51676    1
# 31112    1
# 60182    1
#         ..
# 12109    1
# 60491    1
# 27419    1
# 10434    1
# 53882    1
# Name: count, Length: 5110, dtype: int64
# ----------------------
# gender number of unique values is : 3
# value counts is : gender
# Female    2994
# Male      2115
# Other        1
# Name: count, dtype: int64
# ----------------------
# age number of unique values is : 104
# value counts is : age
# 78.00    102
# 57.00     95
# 52.00     90
# 54.00     87
# 51.00     86
#         ...
# 1.40       3
# 0.48       3
# 0.16       3
# 0.08       2
# 0.40       2
# Name: count, Length: 104, dtype: int64
# ----------------------
# hypertension number of unique values is : 2
# value counts is : hypertension
# 0    4612
# 1     498
# Name: count, dtype: int64
# ----------------------
# heart_disease number of unique values is : 2
# value counts is : heart_disease
# 0    4834
# 1     276
# ...

# %%
df=df.drop(['id'], axis=1)

# %%
corr_matrix = df.corr(numeric_only=True)
plt.figure(figsize=(12, 10))
sns.heatmap(corr_matrix, annot=True, fmt='2g', linewidths=4)
plt.title('Correlation Matrix', fontsize=30)
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %% [markdown]
# Dropping id because its not needed in the correlation matrix

# %% [markdown]
# The higher the value in the correlation matrix means the two values are directly propotional.
#
# The lower the value in the correlation matrix means the two values are inversely proportional.

# %% [markdown]
# model building

# %%
# def handle_outliers(data, columns):
#     for column in columns:
#         if column in data.columns:
#             q1 = df[column].quantile(0.25)
#             q3 = df[column].quantile(0.75)
#             iqr = q3 - q1
#             low_b = q1 - 1.5 * iqr
#             high_b = q3 + 1.5 * iqr

#             outliers = (df[column] < low_b) | (df[column] > high_b)

#             if outliers.any():
#                 print(f"{column}: has outliers")
#                 df[column] = np.where(df[column] < low_b, low_b,
#                                     np.where(df[column] > high_b, high_b, df[column]))
#             else:
#                 print(f"{column}: no outliers")

#     return data

# num_col = df.select_dtypes(include='number').columns
# df = handle_outliers(df, num_col)

# %% [markdown]
# encode

# %%
from sklearn import preprocessing

for col in df.select_dtypes(include=object).columns:
    #label encoder
    label_encoder = preprocessing.LabelEncoder()

    #FIT ENCODER
    label_encoder.fit(df[col].unique())

    #transofrm the column using encoder
    df[col] = label_encoder.transform(df[col])

    print(f'{col}: {df[col].unique()}')
# Out:
# gender: [1 0 2]
# ever_married: [1 0]
# work_type: [2 3 0 4 1]
# Residence_type: [1 0]
# smoking_status: [1 2 3 0]

# %%
df.head()
# Out:
#    gender   age  hypertension  heart_disease  ever_married  work_type  \
# 0       1  67.0             0              1             1          2
# 1       0  61.0             0              0             1          3
# 2       1  80.0             0              1             1          2
# 3       0  49.0             0              0             1          2
# 4       0  79.0             1              0             1          3
#
#    Residence_type  avg_glucose_level        bmi  smoking_status  stroke
# 0               1             228.69  36.600000               1       1
# 1               0             202.21  28.893237               2       1
# 2               0             105.92  32.500000               2       1
# 3               1             171.23  34.400000               3       1
# 4               0             174.12  24.000000               2       1

# %%
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import numpy as np

# Select all columns except 'Stroke' as features
X = df.drop('stroke', axis=1)
y = df['stroke']

# Scale the features
scale = StandardScaler()
x_scale = scale.fit_transform(X)

# Apply PCA for dimensionality reduction
pca = PCA(n_components=2)
X_pca = pca.fit_transform(x_scale)

# Apply SMOTE to the scaled and reduced data
smote = SMOTE(sampling_strategy='auto')
X_resampled, y_resampled = smote.fit_resample(X_pca, y)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size=0.2, random_state=42)

print("Data splitting complete.")
# Out:
# Data splitting complete.

# %% [markdown]
# SMOTE ensures that outputs are equal.
#
# StandardScaler ensures that all features contribute equally to the model
#
# PCA reduces dimensions for

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score,recall_score, f1_score ,classification_report
rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(X_train, y_train)

y_pred = rf.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy}')
# Out:
# Accuracy: 0.838560411311054

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.80      0.83       975
#            1       0.81      0.88      0.84       970
#
#     accuracy                           0.84      1945
#    macro avg       0.84      0.84      0.84      1945
# weighted avg       0.84      0.84      0.84      1945

# %%
df.head()
# Out:
#    gender   age  hypertension  heart_disease  ever_married  work_type  \
# 0       1  67.0             0              1             1          2
# 1       0  61.0             0              0             1          3
# 2       1  80.0             0              1             1          2
# 3       0  49.0             0              0             1          2
# 4       0  79.0             1              0             1          3
#
#    Residence_type  avg_glucose_level        bmi  smoking_status  stroke
# 0               1             228.69  36.600000               1       1
# 1               0             202.21  28.893237               2       1
# 2               0             105.92  32.500000               2       1
# 3               1             171.23  34.400000               3       1
# 4               0             174.12  24.000000               2       1

# %%
import pickle

with open("model.pkl", 'wb') as file:
    pickle.dump(rf, file)
